# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10, 'b':20, 'c':30}

# %%
pd.Series(my_list, name = 'mylist')
# Out:
# 0    10
# 1    20
# 2    30
# Name: mylist, dtype: int64

# %%
pd.Series(my_list, [1, 'e', 'something'])
# Out:
# 1            10
# e            20
# something    30
# dtype: int64

# %%
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4], index = ['USA', 'Germany', 'USSR', 'Japan'])
ser2 = pd.Series([1,2,5,4], index = ['USA', 'Germany', 'Italia', 'Japan'])

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italia     5
# Japan      4
# dtype: int64

# %%
(ser1 + ser2)
# Out:
# Germany    4.0
# Italia     NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
ser1.values
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
ser1.index = [i for i in range(4)]
ser1.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
ser1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
pd.Series(np.random.randint(1,5,15)).unique()
# Out:
# array([2, 4, 1, 3], dtype=int64)

# %%
pd.Series(np.random.randint(1,5,15)).nunique()
# Out:
# 4

# %%
pd.Series(np.random.randint(1,5,15)).value_counts()
# Out:
# 3    6
# 1    4
# 4    3
# 2    2
# dtype: int64

# %%
ser1[~(ser1 < 3) | (ser1 == 4)]
# Out:
# 2    3
# 3    4
# dtype: int64

# %%
ser1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
for i in ser1:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
ser1 < 3
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# dtype: bool

# %% [markdown]
# ## Data Frame

# %%
import pandas as pd
import numpy as np
from numpy.random import seed, randn
seed(101)

# %%
randn(5,4)
# Out:
# array([[ 2.70684984,  0.62813271,  0.90796945,  0.50382575],
#        [ 0.65111795, -0.31931804, -0.84807698,  0.60596535],
#        [-2.01816824,  0.74012206,  0.52881349, -0.58900053],
#        [ 0.18869531, -0.75887206, -0.93323722,  0.95505651],
#        [ 0.19079432,  1.97875732,  2.60596728,  0.68350889]])

# %%
#dataframe adalah sekumpulan series yang ditempel menjadi 1 dan berbagi index. 

df =pd.DataFrame(randn(5,4), index =list('ABCDE'), columns = list('WXYZ'))

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
 pd.Series([1,2,3,4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
df.loc[['E']]
# Out:
#           W         X         Y         Z
# E -0.116773  1.901755  0.238127  1.996652

# %%
df.iloc[[0,3,4]]
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
pd.concat([ df, df.loc[['E']]])
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652
# E -0.116773  1.901755  0.238127  1.996652

# %%
df[['W']]
# Out:
#           W
# A  0.302665
# B -0.134841
# C  0.807706
# D -0.497104
# E -0.116773

# %%
df['W']
# Out:
# A    0.302665
# B   -0.134841
# C    0.807706
# D   -0.497104
# E   -0.116773
# Name: W, dtype: float64

# %%
df.W
# Out:
# A    0.302665
# B   -0.134841
# C    0.807706
# D   -0.497104
# E   -0.116773
# Name: W, dtype: float64

# %% [markdown]
# ## Creating New Column

# %%
df['NEW'] = ['Text',1,2,3,4]

# %%
df
# Out:
#           W         X         Y         Z   NEW
# A  0.302665  1.693723 -1.706086 -1.159119  Text
# B -0.134841  0.390528  0.166905  0.184502     1
# C  0.807706  0.072960  0.638787  0.329646     2
# D -0.497104 -0.754070 -0.943406  0.484752     3
# E -0.116773  1.901755  0.238127  1.996652     4

# %%
df.drop('W', axis =1, inplace = False)
# Out:
#           X         Y         Z   NEW
# A  1.693723 -1.706086 -1.159119  Text
# B  0.390528  0.166905  0.184502     1
# C  0.072960  0.638787  0.329646     2
# D -0.754070 -0.943406  0.484752     3
# E  1.901755  0.238127  1.996652     4

# %%
df
# Out:
#           W         X         Y         Z   NEW
# A  0.302665  1.693723 -1.706086 -1.159119  Text
# B -0.134841  0.390528  0.166905  0.184502     1
# C  0.807706  0.072960  0.638787  0.329646     2
# D -0.497104 -0.754070 -0.943406  0.484752     3
# E -0.116773  1.901755  0.238127  1.996652     4

# %%
df.drop('E')
# Out:
#           W         X         Y         Z   NEW
# A  0.302665  1.693723 -1.706086 -1.159119  Text
# B -0.134841  0.390528  0.166905  0.184502     1
# C  0.807706  0.072960  0.638787  0.329646     2
# D -0.497104 -0.754070 -0.943406  0.484752     3

# %%
df
# Out:
#           W         X         Y         Z   NEW
# A  0.302665  1.693723 -1.706086 -1.159119  Text
# B -0.134841  0.390528  0.166905  0.184502     1
# C  0.807706  0.072960  0.638787  0.329646     2
# D -0.497104 -0.754070 -0.943406  0.484752     3
# E -0.116773  1.901755  0.238127  1.996652     4

# %%
df1 = df.copy()

# %%
df1['New'] = list('ABCDF')

# %%
df1
# Out:
#           W         X         Y         Z   NEW New
# A  0.302665  1.693723 -1.706086 -1.159119  Text   A
# B -0.134841  0.390528  0.166905  0.184502     1   B
# C  0.807706  0.072960  0.638787  0.329646     2   C
# D -0.497104 -0.754070 -0.943406  0.484752     3   D
# E -0.116773  1.901755  0.238127  1.996652     4   F

# %%
df.iloc[0:3]
# Out:
#           W         X         Y         Z   NEW
# A  0.302665  1.693723 -1.706086 -1.159119  Text
# B -0.134841  0.390528  0.166905  0.184502     1
# C  0.807706  0.072960  0.638787  0.329646     2

# %%
df.loc[['A', 'C'], ['W', 'X']]
# Out:
#           W         X
# A  0.302665  1.693723
# C  0.807706  0.072960

# %% [markdown]
# ## Conditional Selection

# %%
# df.drop('New', axis =1, inplace = True)

# %%
df
# Out:
#           W         X         Y         Z   NEW
# A  0.302665  1.693723 -1.706086 -1.159119  Text
# B -0.134841  0.390528  0.166905  0.184502     1
# C  0.807706  0.072960  0.638787  0.329646     2
# D -0.497104 -0.754070 -0.943406  0.484752     3
# E -0.116773  1.901755  0.238127  1.996652     4

# %%
df['W'] > 0
# Out:
# A     True
# B    False
# C     True
# D    False
# E    False
# Name: W, dtype: bool

# %%
df[(df['W'] > 0) | (df['X'] > 1.1)]
# Out:
#           W         X         Y         Z   NEW
# A  0.302665  1.693723 -1.706086 -1.159119  Text
# C  0.807706  0.072960  0.638787  0.329646     2
# E -0.116773  1.901755  0.238127  1.996652     4

# %%
import pandas as pd
import numpy as np

import seaborn as sns
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
IQR = titanic.describe()['age']['75%'] - titanic.describe()['age']['25%']

# %%
batas_bawah = titanic.describe()['age']['25%'] - (1.5*IQR)
batas_atas =titanic.describe()['age']['75%'] + (1.5*IQR)

# %%
batas_bawah
# Out:
# -6.6875

# %%
batas_atas
# Out:
# 64.8125

# %%
titanic['survived'] = titanic['survived'].astype('object')

# %%
titanic.describe(exclude = 'number')
# Out:
#         survived   sex embarked  class  who adult_male deck  embark_town  \
# count        891   891      889    891  891        891  203          889
# unique         2     2        3      3    3          2    7            3
# top            0  male        S  Third  man       True    C  Southampton
# freq         549   577      644    491  537        537   59          644
#
#        alive alone
# count    891   891
# unique     2     2
# top       no  True
# freq     549   537

# %%
titanic.groupby('survived').mean()
# Out:
#             pclass        age     sibsp     parch       fare  adult_male  \
# survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887    0.817851
# 1         1.950292  28.343690  0.473684  0.464912  48.395408    0.257310
#
#              alone
# survived
# 0         0.681239
# 1         0.476608

# %%
titanic.groupby('sex').agg(['mean', 'std', 'min', 'max', 'count', 'sum'])
# Out:
#           pclass                                     age                   \
#             mean      std min max count   sum       mean        std   min
# sex
# female  2.159236  0.85729   1   3   314   678  27.915709  14.110146  0.75
# male    2.389948  0.81358   1   3   577  1379  30.726645  14.678201  0.42
#
#               ... adult_male                         alone                   \
#          max  ...        min    max count    sum      mean       std    min
# sex           ...
# female  63.0  ...      False  False   314    0.0  0.401274  0.490939  False
# male    80.0  ...      False   True   577  537.0  0.712305  0.453081  False
#
#
#          max count    sum
# sex
# female  True   314  126.0
# male    True   577  411.0
#
# [2 rows x 42 columns]

# %%
pd.set_option('display.max_columns', 100)
titanic.groupby('sex').agg(['mean', 'std', 'min', 'max', 'count', 'sum']).T['female'][['survived', 'pclass']]
# Out:
# pclass  mean     2.15924
#         std      0.85729
#         min            1
#         max            3
#         count        314
#         sum          678
# Name: female, dtype: object

# %%
titanic[titanic['deck'].isna()]['class'].value_counts()
# Out:
# Third     479
# Second    168
# First      41
# Name: class, dtype: int64

# %%
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#           W         X         Y         Z   NEW
# 0  0.302665  1.693723 -1.706086 -1.159119  Text
# 1 -0.134841  0.390528  0.166905  0.184502     1
# 2  0.807706  0.072960  0.638787  0.329646     2
# 3 -0.497104 -0.754070 -0.943406  0.484752     3
# 4 -0.116773  1.901755  0.238127  1.996652     4

# %%
titanic
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886        0       2    male  27.0      0      0  13.0000        S  Second
# 887        1       1  female  19.0      0      0  30.0000        S   First
# 888        0       3  female   NaN      1      2  23.4500        S   Third
# 889        1       1    male  26.0      0      0  30.0000        C   First
# 890        0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.sample(5)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 36         1       3    male   NaN      0      0   7.2292        C   Third
# 820        1       1  female  52.0      1      1  93.5000        S   First
# 811        0       3    male  39.0      0      0  24.1500        S   Third
# 887        1       1  female  19.0      0      0  30.0000        S   First
# 247        1       2  female  24.0      0      2  14.5000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 36     man        True  NaN    Cherbourg   yes   True
# 820  woman       False    B  Southampton   yes  False
# 811    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 247  woman       False  NaN  Southampton   yes  False

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null object
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(3), object(6)
# memory usage: 80.6+ KB

# %% [markdown]
# ## Missing Data

# %%
df = pd.DataFrame({'A': [1,2,np.nan],
                  'B': [5, np.nan, np.nan],
                  'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
pd.isna(df)
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
pd.isna(np.nan)
# Out:
# True

# %%
df['A'].isna()
# Out:
# 0    False
# 1    False
# 2     True
# Name: A, dtype: bool

# %%
df[df['B'].isna()]
# Out:
#      A   B  C
# 1  2.0 NaN  2
# 2  NaN NaN  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis = 1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh =2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna('FILL VALUE')
# Out:
#             A           B  C
# 0           1           5  1
# 1           2  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
df.mean()
# Out:
# A    1.5
# B    5.0
# C    2.0
# dtype: float64

# %%
df['A'].fillna(df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df['A'].mean()
# Out:
# 1.5

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(method = 'ffill')
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  2.0  5.0  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %% [markdown]
# ## Merging

# %%
df1 = pd.DataFrame({'A': ['A{}'.format(i) for i in range(4)],
                    'B': ['B{}'.format(i) for i in range(4)],
                    'C': ['C{}'.format(i) for i in range(4)],
                    'D': ['D{}'.format(i) for i in range(4)]
                   }, index = [i for i in range(4)]
                  )

df2 = pd.DataFrame({'A': ['A{}'.format(i) for i in range(4,8)],
                    'B': ['B{}'.format(i) for i in range(4,8)],
                    'C': ['C{}'.format(i) for i in range(4,8)],
                    'D': ['D{}'.format(i) for i in range(4,8)]
                   }, index = [i for i in range(4,8)]
                  )

df3 = pd.DataFrame({'A': ['A{}'.format(i) for i in range(8,12)],
                    'B': ['B{}'.format(i) for i in range(8,12)],
                    'C': ['C{}'.format(i) for i in range(8,12)],
                    'D': ['D{}'.format(i) for i in range(8,12)]
                   }, index = [i for i in range(8,12)]
                  )

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df1
df2
df3
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1, df2, df3], axis =0)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                    'A': ['A{}'.format(i) for i in range(4)],
                    'B': ['B{}'.format(i) for i in range(4)]})

right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                    'C': ['C{}'.format(i) for i in range(4)],
                    'D': ['D{}'.format(i) for i in range(4)]})

# %%
left
right
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left, right,on =['key1', 'key2'], how = 'outer')
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %% [markdown]
# ## Selection

# %%
titanic.head()
# Out:
#   survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0        0       3    male  22.0      1      0   7.2500        S  Third
# 1        1       1  female  38.0      1      0  71.2833        C  First
# 2        1       3  female  26.0      0      0   7.9250        S  Third
# 3        1       1  female  35.0      1      0  53.1000        S  First
# 4        0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone Hello_Hi
# 0    man        True  NaN  Southampton    no  False       Hi
# 1  woman       False    C    Cherbourg   yes  False       Hi
# 2  woman       False  NaN  Southampton   yes   True       Hi
# 3  woman       False    C  Southampton   yes  False       Hi
# 4    man        True  NaN  Southampton    no   True       Hi

# %%
titanic[(titanic['sex'] == 'male') & ~(titanic['class'] == 'First')]['fare'].mean()
# Out:
# 14.342195604395613

# %%
titanic['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
def times_2(x):
    if x < 25:
        return x*2
    else:
        return x

# %%
titanic.apply(print, axis = 1)
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                     22
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Hello_Hi                Hi
# Name: 0, dtype: object
# survived               1
# pclass                 1
# sex               female
# age                   38
# sibsp                  1
# parch                  0
# fare             71.2833
# embarked               C
# class              First
# who                woman
# adult_male         False
# deck                   C
# embark_town    Cherbourg
# alive                yes
# alone              False
# Hello_Hi              Hi
# Name: 1, dtype: object
# survived                 1
# ...

# %%
titanic.head()
# Out:
#   survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0        0       3    male  22.0      1      0   7.2500        S  Third
# 1        1       1  female  38.0      1      0  71.2833        C  First
# 2        1       3  female  26.0      0      0   7.9250        S  Third
# 3        1       1  female  35.0      1      0  53.1000        S  First
# 4        0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone Hello_Hi
# 0    man        True  NaN  Southampton    no  False       Hi
# 1  woman       False    C    Cherbourg   yes  False       Hi
# 2  woman       False  NaN  Southampton   yes   True       Hi
# 3  woman       False    C  Southampton   yes  False       Hi
# 4    man        True  NaN  Southampton    no   True       Hi

# %%
titanic[['age', 'who', 'class']].apply(lambda x: x['age']*2 if x['who'] == 'man' else x['age'],
                                       axis =1)
# Out:
# 0      44.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      70.0
#        ...
# 886    54.0
# 887    19.0
# 888     NaN
# 889    52.0
# 890    64.0
# Length: 891, dtype: float64

# %%
def times_2(x):
    if x < 25:
        return x*2
#     else:
#         return x

# %%
titanic['age'].apply(lambda x: x*2 if x <25 else x)
# Out:
# 0      44.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    38.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic['age'].apply(times_2)
# Out:
# 0      44.0
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 886     NaN
# 887    38.0
# 888     NaN
# 889     NaN
# 890     NaN
# Name: age, Length: 891, dtype: float64

# %%
titanic[['age', 'class']].apply(print, axis =1)
# Out:
# age         22
# class    Third
# Name: 0, dtype: object
# age         38
# class    First
# Name: 1, dtype: object
# age         26
# class    Third
# Name: 2, dtype: object
# age         35
# class    First
# Name: 3, dtype: object
# age         35
# class    Third
# Name: 4, dtype: object
# age        NaN
# class    Third
# Name: 5, dtype: object
# age         54
# class    First
# Name: 6, dtype: object
# age          2
# class    Third
# Name: 7, dtype: object
# age         27
# class    Third
# Name: 8, dtype: object
# age          14
# class    Second
# Name: 9, dtype: object
# age          4
# class    Third
# Name: 10, dtype: object
# age         58
# class    First
# Name: 11, dtype: object
# age         20
# class    Third
# Name: 12, dtype: object
# age         39
# class    Third
# Name: 13, dtype: object
# age         14
# class    Third
# Name: 14, dtype: object
# age          55
# class    Second
# Name: 15, dtype: object
# age          2
# class    Third
# ...

# %%
def class_age(cols):
    if cols['class'] == 'First' and cols['age'] <25:
        return 'Hello'
    else:
        return 'Hi'

# %%
titanic[['age', 'class']].apply(class_age, axis = 1)
# Out:
# 0         Hi
# 1         Hi
# 2         Hi
# 3         Hi
# 4         Hi
#        ...
# 886       Hi
# 887    Hello
# 888       Hi
# 889       Hi
# 890       Hi
# Length: 891, dtype: object

# %%
titanic['Hello_Hi'] = titanic[['age', 'class']].apply(class_age, axis = 1)

# %%
titanic.head()
# Out:
#   survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0        0       3    male  22.0      1      0   7.2500        S  Third
# 1        1       1  female  38.0      1      0  71.2833        C  First
# 2        1       3  female  26.0      0      0   7.9250        S  Third
# 3        1       1  female  35.0      1      0  53.1000        S  First
# 4        0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone Hello_Hi
# 0    man        True  NaN  Southampton    no  False       Hi
# 1  woman       False    C    Cherbourg   yes  False       Hi
# 2  woman       False  NaN  Southampton   yes   True       Hi
# 3  woman       False    C  Southampton   yes  False       Hi
# 4    man        True  NaN  Southampton    no   True       Hi

# %%
titanic['embarked'].apply(lambda x: 'Sesuatu' if pd.isna(x) else x).value_counts()
# Out:
# S          644
# C          168
# Q           77
# Sesuatu      2
# Name: embarked, dtype: int64

# %%
titanic['embarked'].loc[61]
# Out:
# nan

# %%
titanic.pivot_table(index = 'sex', columns = 'pclass', values = 'fare', aggfunc = 'mean')
# Out:
# pclass           1          2          3
# sex
# female  106.125798  21.970121  16.118810
# male     67.226127  19.741782  12.661633
